# %% [markdown]
# # Building your own algorithm container
#
# With Amazon SageMaker, you can package your own algorithms that can than be trained and deployed in the SageMaker environment. This notebook will guide you through an example that shows you how to build a Docker container for SageMaker and use it for training and inference.
#
# By packaging an algorithm in a container, you can bring almost any code to the Amazon SageMaker environment, regardless of programming language, environment, framework, or dependencies.
#
# You can bring your own PyTorch algorithms to SageMaker by extending SageMaker's pre-built container image. (https://docs.aws.amazon.com/sagemaker/latest/dg/your-algorithms.html). We recommend the pre-built container be considered first. This example aims to demonstrate on bringing in your own Mask RCNN model to SageMaker as your own container for training and serving.
#
# 1. [Building your own algorithm container](#Building-your-own-algorithm-container)
#   1. [When should I build my own algorithm container?](#When-should-I-build-my-own-algorithm-container%3F)
#   1. [Permissions](#Permissions)
#   1. [The example](#The-example)
#   1. [The presentation](#The-presentation)
# 1. [Part 1: Packaging and Uploading your Algorithm for use with Amazon SageMaker](#Part-1%3A-Packaging-and-Uploading-your-Algorithm-for-use-with-Amazon-SageMaker)
#     1. [An overview of Docker](#An-overview-of-Docker)
#     1. [How Amazon SageMaker runs your Docker container](#How-Amazon-SageMaker-runs-your-Docker-container)
#       1. [Running your container during training](#Running-your-container-during-training)
#         1. [The input](#The-input)
#         1. [The output](#The-output)
#       1. [Running your container during hosting](#Running-your-container-during-hosting)
#     1. [The parts of the sample container](#The-parts-of-the-sample-container)
#     1. [The Dockerfile](#The-Dockerfile)
#     1. [Building and registering the container](#Building-and-registering-the-container)
#   1. [Testing your algorithm on your local machine or on an Amazon SageMaker notebook instance](#Testing-your-algorithm-on-your-local-machine-or-on-an-Amazon-SageMaker-notebook-instance)
# 1. [Part 2: Using your Algorithm in Amazon SageMaker](#Part-2%3A-Using-your-Algorithm-in-Amazon-SageMaker)
#   1. [Set up the environment](#Set-up-the-environment)
#   1. [Create the session](#Create-the-session)
#   1. [Upload the data for training](#Upload-the-data-for-training)
#   1. [Create an estimator and fit the model](#Create-an-estimator-and-fit-the-model)
#   1. [Hosting your model](#Hosting-your-model)
#     1. [Deploy the model](#Deploy-the-model)
#     2. [Choose some data and use it for a prediction](#Choose-some-data-and-use-it-for-a-prediction)
#     3. [Optional cleanup](#Optional-cleanup)
#   1. [Run Batch Transform Job](#Run-Batch-Transform-Job)
#     1. [Create a Transform Job](#Create-a-Transform-Job)
#     2. [View Output](#View-Output)
#
# _or_ I'm impatient, just [let me see the code](#The-Dockerfile)!
#
# ## When should I build my own algorithm container?
#
# You may not need to create a container to bring your own code to Amazon SageMaker. When you are using a framework (such as Apache MXNet or TensorFlow) that has direct support in SageMaker, you can simply supply the Python code that implements your algorithm using the SDK entry points for that framework. This set of frameworks is continually expanding, so we recommend that you check the current list if your algorithm is written in a common machine learning environment.
#
# Even if there is direct SDK support for your environment or framework, you may find it more effective to build your own container. If the code that implements your algorithm is quite complex on its own or you need special additions to the framework, building your own container may be the right choice.
#
# If there isn't direct SDK support for your environment, don't worry. You'll see in this walk-through that building your own container is quite straightforward.
#
# ## Permissions
#
# Running this notebook requires permissions in addition to the normal `SageMakerFullAccess` permissions. This is because we'll creating new repositories in Amazon ECR. The easiest way to add these permissions is simply to add the managed policy `AmazonEC2ContainerRegistryFullAccess` to the role that you used to start your notebook instance. There's no need to restart your notebook instance when you do this, the new permissions will be available immediately.
#
# ## The example
#
# The Mask R-CNN part of the code is based on the TorchVision Object Detection Funetuning Tutorial (https://pytorch.org/tutorials/intermediate/torchvision_tutorial.html). To learn more about Mask R-CNN, please refer to the original paper published in 2017 (https://arxiv.org/abs/1703.06870).
#
# ## The presentation
#
# This presentation is divided into two parts: _building_ the container and _using_ the container.

# %%
# %%time
import torch
import torchvision
import PIL

model = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=True)
# set it to evaluation mode, as the model behaves differently
# during training and during evaluation
model.eval()

image = PIL.Image.open('./10080.JPG')
image_tensor = torchvision.transforms.functional.to_tensor(image)

# pass a list of (potentially different sized) tensors
# to the model, in 0-1 range. The model will take care of
# batching them together and normalizing
output = model([image_tensor])
# output is a list of dict, containing the postprocessed predictions
output
# Out:
# CPU times: user 15.5 s, sys: 2.39 s, total: 17.9 s
# Wall time: 7.16 s
# [{'boxes': tensor([[334.9097,  38.4953, 396.3930,  80.4492],
#           [118.9440,   3.2597, 636.3796, 400.2156],
#           [337.1837,  37.9822, 383.8517,  80.2761],
#           [123.3981,  40.6704, 639.5287, 423.9186],
#           [341.8828,   2.9619, 608.7013, 116.6271],
#           [276.1492,   8.6352, 626.3828, 130.8172],
#           [226.8409,   2.9692, 635.5309, 165.3420],
#           [390.6584,   0.0000, 532.2007, 103.9375],
#           [163.0966, 102.1330, 475.1101, 189.5265],
#           [171.4036, 105.3198, 338.1162, 178.8008],
#           [159.1063,  73.1969, 178.2280,  93.3574]], grad_fn=<StackBackward>),
#   'labels': tensor([ 3,  8,  8,  3,  8,  3,  8,  8,  3,  3, 85]),
#   'scores': tensor([0.8655, 0.7779, 0.5507, 0.5367, 0.4386, 0.2126, 0.1283, 0.0851, 0.0822,
#           0.0765, 0.0697], grad_fn=<IndexBackward>),
#   'masks': tensor([[[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             ...,
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]]],
#
#
#           [[[0.0000, 0.0000, 0.0000,  ..., 0.0517, 0.0455, 0.0392],
#             [0.0000, 0.0000, 0.0000,  ..., 0.0669, 0.0588, 0.0507],
#             [0.0000, 0.0000, 0.0000,  ..., 0.0820, 0.0721, 0.0622],
#             ...,
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]]],
#
#
#           [[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             ...,
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]]],
#
#
#           ...,
#
#
#           [[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             ...,
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]]],
#
#
#           [[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             ...,
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]]],
#
#
#           [[[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             ...,
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#             [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]]]],
#          grad_fn=<UnsqueezeBackward0>)}]

# %% [markdown]
# # Part 1: Packaging and Uploading your Algorithm for use with Amazon SageMaker
#
# ### An overview of Docker
#
# If you're familiar with Docker already, you can skip ahead to the next section.
#
# For many data scientists, Docker containers are a new concept, but they are not difficult, as you'll see here.
#
# Docker provides a simple way to package arbitrary code into an _image_ that is totally self-contained. Once you have an image, you can use Docker to run a _container_ based on that image. Running a container is just like running a program on the machine except that the container creates a fully self-contained environment for the program to run. Containers are isolated from each other and from the host environment, so the way you set up your program is the way it runs, no matter where you run it.
#
# Docker is more powerful than environment managers like conda or virtualenv because (a) it is completely language independent and (b) it comprises your whole operating environment, including startup commands, environment variable, etc.
#
# In some ways, a Docker container is like a virtual machine, but it is much lighter weight. For example, a program running in a container can start in less than a second and many containers can run on the same physical machine or virtual machine instance.
#
# Docker uses a simple file called a `Dockerfile` to specify how the image is assembled. We'll see an example of that below. You can build your Docker images based on Docker images built by yourself or others, which can simplify things quite a bit.
#
# Docker has become very popular in the programming and devops communities for its flexibility and well-defined specification of the code to be run. It is the underpinning of many services built in the past few years, such as [Amazon ECS].
#
# Amazon SageMaker uses Docker to allow users to train and deploy arbitrary algorithms.
#
# In Amazon SageMaker, Docker containers are invoked in a certain way for training and a slightly different way for hosting. The following sections outline how to build containers for the SageMaker environment.
#
# Some helpful links:
#
# * [Docker home page](http://www.docker.com)
# * [Getting started with Docker](https://docs.docker.com/get-started/)
# * [Dockerfile reference](https://docs.docker.com/engine/reference/builder/)
# * [`docker run` reference](https://docs.docker.com/engine/reference/run/)
#
# [Amazon ECS]: https://aws.amazon.com/ecs/
#
# ### How Amazon SageMaker runs your Docker container
#
# Because you can run the same image in training or hosting, Amazon SageMaker runs your container with the argument `train` or `serve`. How your container processes this argument depends on the container:
#
# * In the example here, we don't define an `ENTRYPOINT` in the Dockerfile so Docker will run the command `train` at training time and `serve` at serving time. In this example, we define these as executable Python scripts, but they could be any program that we want to start in that environment.
# * If you specify a program as an `ENTRYPOINT` in the Dockerfile, that program will be run at startup and its first argument will be `train` or `serve`. The program can then look at that argument and decide what to do.
# * If you are building separate containers for training and hosting (or building only for one or the other), you can define a program as an `ENTRYPOINT` in the Dockerfile and ignore (or verify) the first argument passed in.
#
# #### Running your container during training
#
# When Amazon SageMaker runs training, your `train` script is run just like a regular Python program. A number of files are laid out for your use, under the `/opt/ml` directory:
#
#     /opt/ml
#     ├── input
#     │   ├── config
#     │   │   ├── hyperparameters.json
#     │   │   └── resourceConfig.json
#     │   └── data
#     │       └── <channel_name>
#     │           └── <input data>
#     ├── model
#     │   └── <model files>
#     └── output
#         └── failure
#
# ##### The input
#
# * `/opt/ml/input/config` contains information to control how your program runs. `hyperparameters.json` is a JSON-formatted dictionary of hyperparameter names to values. These values will always be strings, so you may need to convert them. `resourceConfig.json` is a JSON-formatted file that describes the network layout used for distributed training. Since scikit-learn doesn't support distributed training, we'll ignore it here.
# * `/opt/ml/input/data/<channel_name>/` (for File mode) contains the input data for that channel. The channels are created based on the call to CreateTrainingJob but it's generally important that channels match what the algorithm expects. The files for each channel will be copied from S3 to this directory, preserving the tree structure indicated by the S3 key structure.
# * `/opt/ml/input/data/<channel_name>_<epoch_number>` (for Pipe mode) is the pipe for a given epoch. Epochs start at zero and go up by one each time you read them. There is no limit to the number of epochs that you can run, but you must close each pipe before reading the next epoch.
#
# ##### The output
#
# * `/opt/ml/model/` is the directory where you write the model that your algorithm generates. Your model can be in any format that you want. It can be a single file or a whole directory tree. SageMaker will package any files in this directory into a compressed tar archive file. This file will be available at the S3 location returned in the `DescribeTrainingJob` result.
# * `/opt/ml/output` is a directory where the algorithm can write a file `failure` that describes why the job failed. The contents of this file will be returned in the `FailureReason` field of the `DescribeTrainingJob` result. For jobs that succeed, there is no reason to write this file as it will be ignored.
#
# #### Running your container during hosting
#
# Hosting has a very different model than training because hosting is reponding to inference requests that come in via HTTP. In this example, we use our recommended Python serving stack to provide robust and scalable serving of inference requests:
#
# ![Request serving stack](stack.png)
#
# This stack is implemented in the sample code here and you can mostly just leave it alone.
#
# Amazon SageMaker uses two URLs in the container:
#
# * `/ping` will receive `GET` requests from the infrastructure. Your program returns 200 if the container is up and accepting requests.
# * `/invocations` is the endpoint that receives client inference `POST` requests. The format of the request and the response is up to the algorithm. If the client supplied `ContentType` and `Accept` headers, these will be passed in as well.
#
# The container will have the model files in the same place they were written during training:
#
#     /opt/ml
#     └── model
#         └── <model files>

# %% [markdown]
# ### The parts of the sample container
#
# In the `container` directory are all the components you need to package the sample algorithm for Amazon SageMager:
#
#     .
#     ├── Dockerfile
#     ├── build_and_push.sh
#     └── mask_r_cnn
#         ├── nginx.conf
#         ├── predictor.py
#         ├── serve
#         ├── wsgi.py
#         ├── transforms.py
#         ├── utils.py
#         ├── coco_eval.py
#         ├── coco_utils.py
#         ├── engine.py
#         └── helper.py
#
#
#
# Let's discuss each of these in turn:
#
# * __`Dockerfile`__ describes how to build your Docker container image. More details below.
# * __`build_and_push.sh`__ is a script that uses the Dockerfile to build your container images and then pushes it to ECR. We'll invoke the commands directly later in this notebook, but you can just copy and run the script for your own algorithms.
# * __`mask_r_cnn`__ is the directory which contains the files that will be installed in the container.
#
#
# In this simple application, we only install five files in the container. You may only need that many or, if you have many supporting routines, you may wish to install more. These five show the standard structure of our Python containers, although you are free to choose a different toolset and therefore could have a different layout. If you're writing in a different programming language, you'll certainly have a different layout depending on the frameworks and tools you choose.
#
# The files that we'll put in the container are:
#
# * __`nginx.conf`__ is the configuration file for the nginx front-end. Generally, you should be able to take this file as-is.
# * __`predictor.py`__ is the program that actually implements the Flask web server and the decision tree predictions for this app.
# * __`serve`__ is the program started when the container is started for hosting. It simply launches the gunicorn server which runs multiple instances of the Flask app defined in `predictor.py`. You should be able to take this file as-is.
# * __`train`__ is the program that is invoked when the container is run for training.
# * __`wsgi.py`__ is a small wrapper used to invoke the Flask app. You should be able to take this file as-is.
#
# We have customized `train.py` and `predictor.py` for fine tuning Mask R-CNN during training, and for loading tuned model, deserializing request data, making prediction, and sending back the serialized results.

# %% [markdown]
# ### The Dockerfile
#
# The Dockerfile describes the image that we want to build. You can think of it as describing the complete operating system installation of the system that you want to run. A Docker container running is quite a bit lighter than a full operating system, however, because it takes advantage of Linux on the host machine for the basic operations.
#
# For the Python science stack, we will start from a standard Ubuntu installation and run the normal tools to install the things needed by scikit-learn. Finally, we add the code that implements our specific algorithm to the container and set up the right environment to run under.
#
# Along the way, we clean up extra space. This makes the container smaller and faster to start.
#
# Let's look at the Dockerfile for the example:

# %%
# !cat container/Dockerfile
# Out:
# ARG REGISTRY_URI
# FROM ${REGISTRY_URI}/pytorch-inference:1.5.0-cpu-py36-ubuntu16.04
#
# RUN mkdir -p /opt/ml/model
#
# # COPY package/ /opt/ml/code/package/
#
# # COPY serve.py /opt/ml/model/code/
#
# ENV PYTHONUNBUFFERED=TRUE
# ENV PYTHONDONTWRITEBYTECODE=TRUE
# ENV PATH="/opt/program:${PATH}"
#
# ##########################################################################################
# # SageMaker requirements
# ##########################################################################################
# ## install flask
# RUN pip install networkx==2.3 flask gevent gunicorn boto3 pycocotools scikit-image scikit-learn==0.22 torch==1.4 torchvision==0.5.0  fastai thinc  Pillow -i https://opentuna.cn/pypi/web/simple
#
# ### Install nginx notebook
# RUN apt-get -y update && apt-get install -y --no-install-recommends \
#          wget \
#          nginx \
#          ca-certificates \
#     && rm -rf /var/lib/apt/lists/*
#
# # forward request and error logs to docker log collector
# RUN ln -sf /dev/stdout /var/log/nginx/access.log
# RUN ln -sf /dev/stderr /var/log/nginx/error.log
#
# ENV PYTHONUNBUFFERED=TRUE
# ENV PYTHONDONTWRITEBYTECODE=TRUE
# ENV PATH="/opt/program:${PATH}"
#
# # Set up the program in the image
# COPY mask_r_cnn /opt/program
# WORKDIR /opt/program

# %% [markdown]
# ### Building and registering the container
#
# The following shell code shows how to build the container image using `docker build` and push the container image to ECR using `docker push`. This code is also available as the shell script `container/build-and-push.sh`, which you can run as `build-and-push.sh decision_trees_sample` to build the image `decision_trees_sample`.
#
# This code looks for an ECR repository in the account you're using and the current default region (if you're using a SageMaker notebook instance, this will be the region where the notebook instance was created). If the repository doesn't exist, the script will create it.

# %%
# %%sh
#
# # The name of our algorithm
# algorithm_name=mask-r-cnn
#
# cd container
#
# chmod +x mask_r_cnn/train
# chmod +x mask_r_cnn/serve
#
# account=$(aws sts get-caller-identity --query Account --output text)
#
# # Get the region defined in the current configuration (default to us-west-2 if none defined)
# region=$(aws configure get region)
# region=${region:-us-east-1}
#
# fullname="${account}.dkr.ecr.${region}.amazonaws.com/${algorithm_name}:latest"
#
# # If the repository doesn't exist in ECR, create it.
# aws ecr describe-repositories --repository-names "${algorithm_name}" > /dev/null 2>&1
#
# if [ $? -ne 0 ]
# then
#     aws ecr create-repository --repository-name "${algorithm_name}" > /dev/null
# fi
#
# # Get the login command from ECR and execute it directly
# $(aws ecr get-login --region ${region} --no-include-email)
#
# # Build the docker image locally with the image name and then push it to ECR
# # with the full name.
#
# docker build  -t ${algorithm_name} .
# docker tag ${algorithm_name} ${fullname}
#
# docker push ${fullname}
# Out:
# Process is interrupted.

# %% [markdown]
# # Part 2: Using your Algorithm in Amazon SageMaker
#
# Once you have your container packaged, you can use it to train models and use the model for hosting or batch transforms. Let's do that with the algorithm we made above.
#
# ## Set up the environment
#
# Here we specify a bucket to use and the role that will be used for working with SageMaker.

# %%
# Define IAM role
import boto3
import re

import os
import numpy as np
import pandas as pd
from sagemaker import get_execution_role

role = get_execution_role()

# %% [markdown]
# ## Create the session
#
# The session remembers our connection parameters to SageMaker. We'll use it to perform all of our SageMaker operations.

# %%
import sagemaker as sage
from time import gmtime, strftime

sess = sage.Session()

bucket = sess.default_bucket()
prefix = 'DEMO-Mask-R-CNN'

# %% [markdown]
# ## Upload the data for training
#
# When training large models with huge amounts of data, you'll typically use big data tools, like Amazon Athena, AWS Glue, or Amazon EMR, to create your data in S3. For the purposes of this example, we're using some the classic [Iris dataset](https://en.wikipedia.org/wiki/Iris_flower_data_set), which we have included.
#
# We can use use the tools provided by the SageMaker Python SDK to upload the data to a default bucket.

# %% [markdown]
# First, we need to download data for this sample notebook and upload it to S3.

# %%
# %%bash
# aws s3 cp ./data/modelc_sub s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub --recursive
# Out:
# upload: data/modelc_sub/.DS_Store to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/.DS_Store
# upload: data/modelc_sub/label/10006.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10006.json
# upload: data/modelc_sub/label/1.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1.json
# upload: data/modelc_sub/label/10002.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10002.json
# upload: data/modelc_sub/label/10010.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10010.json
# upload: data/modelc_sub/label/10009.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10009.json
# upload: data/modelc_sub/label/10011.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10011.json
# upload: data/modelc_sub/label/10004.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10004.json
# upload: data/modelc_sub/label/10027.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10027.json
# upload: data/modelc_sub/label/10034.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10034.json
# upload: data/modelc_sub/label/10036.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10036.json
# upload: data/modelc_sub/label/10042.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10042.json
# upload: data/modelc_sub/label/1003.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1003.json
# upload: data/modelc_sub/label/10043.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10043.json
# upload: data/modelc_sub/label/10045.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10045.json
# upload: data/modelc_sub/label/10049.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10049.json
# upload: data/modelc_sub/label/10063.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10063.json
# upload: data/modelc_sub/label/10066.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10066.json
# upload: data/modelc_sub/label/10054.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10054.json
# upload: data/modelc_sub/label/10050.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10050.json
# upload: data/modelc_sub/label/1005.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1005.json
# upload: data/modelc_sub/label/10068.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10068.json
# upload: data/modelc_sub/label/10065.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10065.json
# upload: data/modelc_sub/label/10080.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10080.json
# upload: data/modelc_sub/label/10074.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10074.json
# upload: data/modelc_sub/label/10081.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10081.json
# upload: data/modelc_sub/label/10072.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10072.json
# upload: data/modelc_sub/label/10079.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10079.json
# upload: data/modelc_sub/label/10098.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10098.json
# upload: data/modelc_sub/label/10082.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10082.json
# upload: data/modelc_sub/label/10102.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10102.json
# upload: data/modelc_sub/label/10112.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10112.json
# upload: data/modelc_sub/label/10100.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10100.json
# upload: data/modelc_sub/label/10103.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10103.json
# upload: data/modelc_sub/label/10090.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10090.json
# upload: data/modelc_sub/label/10118.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10118.json
# upload: data/modelc_sub/label/10114.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10114.json
# upload: data/modelc_sub/label/10126.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10126.json
# upload: data/modelc_sub/label/10115.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10115.json
# upload: data/modelc_sub/label/1013.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1013.json
# upload: data/modelc_sub/label/1014.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1014.json
# upload: data/modelc_sub/label/10140.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10140.json
# upload: data/modelc_sub/label/10138.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10138.json
# upload: data/modelc_sub/label/10137.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10137.json
# upload: data/modelc_sub/label/10151.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10151.json
# upload: data/modelc_sub/label/10149.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10149.json
# upload: data/modelc_sub/label/10152.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10152.json
# upload: data/modelc_sub/label/10156.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10156.json
# upload: data/modelc_sub/label/10157.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10157.json
# upload: data/modelc_sub/label/10159.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10159.json
# upload: data/modelc_sub/label/10160.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10160.json
# upload: data/modelc_sub/label/10158.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10158.json
# upload: data/modelc_sub/label/1016.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1016.json
# upload: data/modelc_sub/label/10165.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10165.json
# upload: data/modelc_sub/label/10164.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10164.json
# upload: data/modelc_sub/label/1017.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1017.json
# upload: data/modelc_sub/label/10166.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10166.json
# upload: data/modelc_sub/label/10179.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10179.json
# upload: data/modelc_sub/label/10163.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10163.json
# upload: data/modelc_sub/label/10171.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10171.json
# upload: data/modelc_sub/label/10185.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10185.json
# upload: data/modelc_sub/label/1019.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1019.json
# upload: data/modelc_sub/label/10193.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10193.json
# upload: data/modelc_sub/label/10182.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10182.json
# upload: data/modelc_sub/label/10194.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10194.json
# upload: data/modelc_sub/label/10201.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10201.json
# upload: data/modelc_sub/label/10198.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10198.json
# upload: data/modelc_sub/label/10196.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10196.json
# upload: data/modelc_sub/label/10211.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10211.json
# upload: data/modelc_sub/label/10203.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10203.json
# upload: data/modelc_sub/label/10207.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10207.json
# upload: data/modelc_sub/label/10202.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10202.json
# upload: data/modelc_sub/label/10209.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10209.json
# upload: data/modelc_sub/label/10212.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10212.json
# upload: data/modelc_sub/label/10223.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10223.json
# upload: data/modelc_sub/label/10214.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10214.json
# upload: data/modelc_sub/label/10218.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10218.json
# upload: data/modelc_sub/label/10217.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10217.json
# upload: data/modelc_sub/label/10227.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10227.json
# upload: data/modelc_sub/label/10236.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10236.json
# upload: data/modelc_sub/label/10225.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10225.json
# upload: data/modelc_sub/label/10230.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10230.json
# upload: data/modelc_sub/label/10231.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10231.json
# upload: data/modelc_sub/label/10237.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10237.json
# upload: data/modelc_sub/label/10238.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10238.json
# upload: data/modelc_sub/label/10241.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10241.json
# upload: data/modelc_sub/label/10239.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10239.json
# upload: data/modelc_sub/label/10242.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10242.json
# upload: data/modelc_sub/label/10257.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10257.json
# upload: data/modelc_sub/label/10246.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10246.json
# upload: data/modelc_sub/label/10252.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10252.json
# upload: data/modelc_sub/label/10243.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10243.json
# upload: data/modelc_sub/label/10254.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10254.json
# upload: data/modelc_sub/label/10263.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10263.json
# upload: data/modelc_sub/label/10270.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10270.json
# upload: data/modelc_sub/label/1027.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1027.json
# upload: data/modelc_sub/label/10250.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10250.json
# upload: data/modelc_sub/label/10274.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10274.json
# upload: data/modelc_sub/label/10277.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10277.json
# upload: data/modelc_sub/label/10278.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10278.json
# upload: data/modelc_sub/label/10279.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10279.json
# upload: data/modelc_sub/label/1028.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1028.json
# upload: data/modelc_sub/label/10275.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10275.json
# upload: data/modelc_sub/label/10281.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10281.json
# upload: data/modelc_sub/label/10286.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10286.json
# upload: data/modelc_sub/label/1029.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1029.json
# upload: data/modelc_sub/label/10280.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10280.json
# upload: data/modelc_sub/label/10284.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10284.json
# upload: data/modelc_sub/label/10290.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10290.json
# upload: data/modelc_sub/label/10298.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10298.json
# upload: data/modelc_sub/label/10224.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10224.json
# upload: data/modelc_sub/label/10295.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10295.json
# upload: data/modelc_sub/label/10300.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10300.json
# upload: data/modelc_sub/label/10294.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10294.json
# upload: data/modelc_sub/label/10297.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10297.json
# upload: data/modelc_sub/label/10292.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10292.json
# upload: data/modelc_sub/label/10302.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10302.json
# upload: data/modelc_sub/label/10301.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10301.json
# upload: data/modelc_sub/label/10311.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10311.json
# upload: data/modelc_sub/label/10305.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10305.json
# upload: data/modelc_sub/label/1031.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1031.json
# upload: data/modelc_sub/label/10313.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10313.json
# upload: data/modelc_sub/label/10310.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10310.json
# upload: data/modelc_sub/label/10316.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10316.json
# upload: data/modelc_sub/label/10324.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10324.json
# upload: data/modelc_sub/label/10327.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10327.json
# upload: data/modelc_sub/label/10331.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10331.json
# upload: data/modelc_sub/label/1033.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1033.json
# upload: data/modelc_sub/label/10323.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10323.json
# upload: data/modelc_sub/label/1032.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1032.json
# upload: data/modelc_sub/label/10335.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10335.json
# upload: data/modelc_sub/label/10334.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10334.json
# upload: data/modelc_sub/label/10333.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10333.json
# upload: data/modelc_sub/label/10344.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10344.json
# upload: data/modelc_sub/label/10336.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10336.json
# upload: data/modelc_sub/label/1034.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1034.json
# upload: data/modelc_sub/label/10348.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10348.json
# upload: data/modelc_sub/label/10368.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10368.json
# upload: data/modelc_sub/label/10362.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10362.json
# upload: data/modelc_sub/label/1036.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1036.json
# upload: data/modelc_sub/label/10351.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10351.json
# upload: data/modelc_sub/label/10363.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10363.json
# upload: data/modelc_sub/label/10355.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10355.json
# upload: data/modelc_sub/label/10371.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10371.json
# upload: data/modelc_sub/label/10375.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10375.json
# upload: data/modelc_sub/label/10373.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10373.json
# upload: data/modelc_sub/label/1038.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1038.json
# upload: data/modelc_sub/label/10378.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10378.json
# upload: data/modelc_sub/label/10379.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10379.json
# upload: data/modelc_sub/label/10383.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10383.json
# upload: data/modelc_sub/label/10387.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10387.json
# upload: data/modelc_sub/label/10382.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10382.json
# upload: data/modelc_sub/label/10385.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10385.json
# upload: data/modelc_sub/label/10392.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10392.json
# upload: data/modelc_sub/label/10395.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10395.json
# upload: data/modelc_sub/label/10397.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10397.json
# upload: data/modelc_sub/label/10402.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10402.json
# upload: data/modelc_sub/label/10413.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10413.json
# upload: data/modelc_sub/label/10406.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10406.json
# upload: data/modelc_sub/label/1041.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1041.json
# upload: data/modelc_sub/label/10418.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10418.json
# upload: data/modelc_sub/label/10420.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10420.json
# upload: data/modelc_sub/label/10431.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10431.json
# upload: data/modelc_sub/label/10408.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10408.json
# upload: data/modelc_sub/label/10422.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10422.json
# upload: data/modelc_sub/label/10434.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10434.json
# upload: data/modelc_sub/label/10423.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10423.json
# upload: data/modelc_sub/label/10435.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10435.json
# upload: data/modelc_sub/label/10416.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10416.json
# upload: data/modelc_sub/label/10440.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10440.json
# upload: data/modelc_sub/label/10448.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10448.json
# upload: data/modelc_sub/label/1045.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1045.json
# upload: data/modelc_sub/label/10450.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10450.json
# upload: data/modelc_sub/label/10465.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10465.json
# upload: data/modelc_sub/label/1046.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1046.json
# upload: data/modelc_sub/label/10467.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10467.json
# upload: data/modelc_sub/label/10482.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10482.json
# upload: data/modelc_sub/label/10492.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10492.json
# upload: data/modelc_sub/label/1047.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1047.json
# upload: data/modelc_sub/label/10488.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10488.json
# upload: data/modelc_sub/label/10487.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10487.json
# upload: data/modelc_sub/label/10476.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10476.json
# upload: data/modelc_sub/label/10486.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10486.json
# upload: data/modelc_sub/label/10518.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10518.json
# upload: data/modelc_sub/label/10512.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10512.json
# upload: data/modelc_sub/label/10500.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10500.json
# upload: data/modelc_sub/label/10489.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10489.json
# upload: data/modelc_sub/label/10525.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10525.json
# upload: data/modelc_sub/label/10522.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10522.json
# upload: data/modelc_sub/label/10521.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10521.json
# upload: data/modelc_sub/label/10553.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10553.json
# upload: data/modelc_sub/label/10558.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10558.json
# upload: data/modelc_sub/label/10559.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10559.json
# upload: data/modelc_sub/label/10597.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10597.json
# upload: data/modelc_sub/label/1053.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1053.json
# upload: data/modelc_sub/label/10608.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10608.json
# upload: data/modelc_sub/label/10548.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10548.json
# upload: data/modelc_sub/label/10648.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10648.json
# upload: data/modelc_sub/label/10615.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10615.json
# upload: data/modelc_sub/label/10661.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10661.json
# upload: data/modelc_sub/label/10667.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10667.json
# upload: data/modelc_sub/label/10634.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10634.json
# upload: data/modelc_sub/label/10673.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10673.json
# upload: data/modelc_sub/label/10681.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10681.json
# upload: data/modelc_sub/label/10687.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10687.json
# upload: data/modelc_sub/label/1077.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1077.json
# upload: data/modelc_sub/label/10705.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/10705.json
# upload: data/modelc_sub/label/1085.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1085.json
# upload: data/modelc_sub/label/108.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/108.json
# upload: data/modelc_sub/label/1104.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1104.json
# upload: data/modelc_sub/label/1133.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1133.json
# upload: data/modelc_sub/label/1120.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1120.json
# upload: data/modelc_sub/label/1136.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1136.json
# upload: data/modelc_sub/label/112.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/112.json
# upload: data/modelc_sub/label/1160.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1160.json
# upload: data/modelc_sub/label/1192.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1192.json
# upload: data/modelc_sub/label/1194.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1194.json
# upload: data/modelc_sub/label/1237.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1237.json
# upload: data/modelc_sub/label/1214.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1214.json
# upload: data/modelc_sub/label/1183.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1183.json
# upload: data/modelc_sub/label/125.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/125.json
# upload: data/modelc_sub/label/1265.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1265.json
# upload: data/modelc_sub/label/1257.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1257.json
# upload: data/modelc_sub/label/1196.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1196.json
# upload: data/modelc_sub/label/1306.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1306.json
# upload: data/modelc_sub/label/1333.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1333.json
# upload: data/modelc_sub/label/1374.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1374.json
# upload: data/modelc_sub/label/1362.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1362.json
# upload: data/modelc_sub/label/1409.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1409.json
# upload: data/modelc_sub/label/1437.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1437.json
# upload: data/modelc_sub/label/1405.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1405.json
# upload: data/modelc_sub/label/144.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/144.json
# upload: data/modelc_sub/label/1530.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1530.json
# upload: data/modelc_sub/label/1465.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1465.json
# upload: data/modelc_sub/label/1468.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1468.json
# upload: data/modelc_sub/label/1577.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1577.json
# upload: data/modelc_sub/label/1641.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1641.json
# upload: data/modelc_sub/label/1572.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1572.json
# upload: data/modelc_sub/label/1693.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1693.json
# upload: data/modelc_sub/label/1694.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1694.json
# upload: data/modelc_sub/label/1699.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1699.json
# upload: data/modelc_sub/label/1733.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1733.json
# upload: data/modelc_sub/label/1658.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1658.json
# upload: data/modelc_sub/label/172.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/172.json
# upload: data/modelc_sub/label/1740.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1740.json
# upload: data/modelc_sub/label/176.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/176.json
# upload: data/modelc_sub/label/1745.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1745.json
# upload: data/modelc_sub/label/1771.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1771.json
# upload: data/modelc_sub/label/1887.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1887.json
# upload: data/modelc_sub/label/1790.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1790.json
# upload: data/modelc_sub/label/1848.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1848.json
# upload: data/modelc_sub/label/1907.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1907.json
# upload: data/modelc_sub/label/1892.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1892.json
# upload: data/modelc_sub/label/1957.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1957.json
# upload: data/modelc_sub/label/1888.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1888.json
# upload: data/modelc_sub/label/1913.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1913.json
# upload: data/modelc_sub/label/1945.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1945.json
# upload: data/modelc_sub/label/1959.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/1959.json
# upload: data/modelc_sub/label/2034.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2034.json
# upload: data/modelc_sub/label/2046.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2046.json
# upload: data/modelc_sub/label/2110.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2110.json
# upload: data/modelc_sub/label/2079.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2079.json
# upload: data/modelc_sub/label/2156.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2156.json
# upload: data/modelc_sub/label/2172.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2172.json
# upload: data/modelc_sub/label/2217.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2217.json
# upload: data/modelc_sub/label/2266.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2266.json
# upload: data/modelc_sub/label/2398.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2398.json
# upload: data/modelc_sub/label/2296.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2296.json
# upload: data/modelc_sub/label/2338.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2338.json
# upload: data/modelc_sub/label/2394.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2394.json
# upload: data/modelc_sub/label/2416.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2416.json
# upload: data/modelc_sub/label/2474.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2474.json
# upload: data/modelc_sub/label/2475.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2475.json
# upload: data/modelc_sub/label/2526.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2526.json
# upload: data/modelc_sub/label/2506.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2506.json
# upload: data/modelc_sub/label/2492.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2492.json
# upload: data/modelc_sub/label/2582.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2582.json
# upload: data/modelc_sub/label/2579.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2579.json
# upload: data/modelc_sub/label/259.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/259.json
# upload: data/modelc_sub/label/2621.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2621.json
# upload: data/modelc_sub/label/2652.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2652.json
# upload: data/modelc_sub/label/2673.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2673.json
# upload: data/modelc_sub/label/2717.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2717.json
# upload: data/modelc_sub/label/2723.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2723.json
# upload: data/modelc_sub/label/271.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/271.json
# upload: data/modelc_sub/label/2674.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2674.json
# upload: data/modelc_sub/label/2754.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2754.json
# upload: data/modelc_sub/label/2814.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2814.json
# upload: data/modelc_sub/label/2934.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2934.json
# upload: data/modelc_sub/label/2852.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2852.json
# upload: data/modelc_sub/label/2970.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2970.json
# upload: data/modelc_sub/label/2724.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2724.json
# upload: data/modelc_sub/label/2972.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2972.json
# upload: data/modelc_sub/label/2980.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2980.json
# upload: data/modelc_sub/label/3001.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3001.json
# upload: data/modelc_sub/label/2919.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/2919.json
# upload: data/modelc_sub/label/3002.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3002.json
# upload: data/modelc_sub/label/3010.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3010.json
# upload: data/modelc_sub/label/3017.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3017.json
# upload: data/modelc_sub/label/3035.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3035.json
# upload: data/modelc_sub/label/303.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/303.json
# upload: data/modelc_sub/label/3033.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3033.json
# upload: data/modelc_sub/label/3038.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3038.json
# upload: data/modelc_sub/label/3134.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3134.json
# upload: data/modelc_sub/label/3203.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3203.json
# upload: data/modelc_sub/label/3049.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3049.json
# upload: data/modelc_sub/label/3252.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3252.json
# upload: data/modelc_sub/label/3243.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3243.json
# upload: data/modelc_sub/label/3141.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3141.json
# upload: data/modelc_sub/label/326.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/326.json
# upload: data/modelc_sub/label/3257.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3257.json
# upload: data/modelc_sub/label/3283.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3283.json
# upload: data/modelc_sub/label/3488.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3488.json
# upload: data/modelc_sub/label/3526.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3526.json
# upload: data/modelc_sub/label/3460.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3460.json
# upload: data/modelc_sub/label/3521.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3521.json
# upload: data/modelc_sub/label/3685.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3685.json
# upload: data/modelc_sub/label/3645.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3645.json
# upload: data/modelc_sub/label/37.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/37.json
# upload: data/modelc_sub/label/3686.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3686.json
# upload: data/modelc_sub/label/371.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/371.json
# upload: data/modelc_sub/label/3505.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3505.json
# upload: data/modelc_sub/label/3715.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3715.json
# upload: data/modelc_sub/label/3761.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3761.json
# upload: data/modelc_sub/label/3794.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3794.json
# upload: data/modelc_sub/label/384.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/384.json
# upload: data/modelc_sub/label/383.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/383.json
# upload: data/modelc_sub/label/3861.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3861.json
# upload: data/modelc_sub/label/3873.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3873.json
# upload: data/modelc_sub/label/3875.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3875.json
# upload: data/modelc_sub/label/3881.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3881.json
# upload: data/modelc_sub/label/3921.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3921.json
# upload: data/modelc_sub/label/3846.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3846.json
# upload: data/modelc_sub/label/3933.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3933.json
# upload: data/modelc_sub/label/3888.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3888.json
# upload: data/modelc_sub/label/3845.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3845.json
# upload: data/modelc_sub/label/3938.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3938.json
# upload: data/modelc_sub/label/3940.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3940.json
# upload: data/modelc_sub/label/395.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/395.json
# upload: data/modelc_sub/label/3941.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3941.json
# upload: data/modelc_sub/label/3975.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/3975.json
# upload: data/modelc_sub/label/4029.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4029.json
# upload: data/modelc_sub/label/4028.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4028.json
# upload: data/modelc_sub/label/4061.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4061.json
# upload: data/modelc_sub/label/4127.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4127.json
# upload: data/modelc_sub/label/4144.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4144.json
# upload: data/modelc_sub/label/4200.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4200.json
# upload: data/modelc_sub/label/404.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/404.json
# upload: data/modelc_sub/label/4216.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4216.json
# upload: data/modelc_sub/label/4067.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4067.json
# upload: data/modelc_sub/label/4132.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4132.json
# upload: data/modelc_sub/label/4171.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4171.json
# upload: data/modelc_sub/label/4273.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4273.json
# upload: data/modelc_sub/label/4237.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4237.json
# upload: data/modelc_sub/label/4239.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4239.json
# upload: data/modelc_sub/label/4294.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4294.json
# upload: data/modelc_sub/label/4303.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4303.json
# upload: data/modelc_sub/label/4362.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4362.json
# upload: data/modelc_sub/label/437.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/437.json
# upload: data/modelc_sub/label/4345.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4345.json
# upload: data/modelc_sub/label/4386.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4386.json
# upload: data/modelc_sub/.ipynb_checkpoints/1-checkpoint.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/.ipynb_checkpoints/1-checkpoint.json
# upload: data/modelc_sub/label/4420.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4420.json
# upload: data/modelc_sub/label/4406.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4406.json
# upload: data/modelc_sub/label/4415.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4415.json
# upload: data/modelc_sub/label/4422.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4422.json
# upload: data/modelc_sub/label/4454.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4454.json
# upload: data/modelc_sub/label/4423.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4423.json
# upload: data/modelc_sub/label/451.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/451.json
# upload: data/modelc_sub/label/4567.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4567.json
# upload: data/modelc_sub/label/4332.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4332.json
# upload: data/modelc_sub/label/4472.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4472.json
# upload: data/modelc_sub/label/4561.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4561.json
# upload: data/modelc_sub/label/452.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/452.json
# upload: data/modelc_sub/label/4555.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4555.json
# upload: data/modelc_sub/label/4587.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4587.json
# upload: data/modelc_sub/label/4593.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4593.json
# upload: data/modelc_sub/label/4637.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4637.json
# upload: data/modelc_sub/label/4649.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4649.json
# upload: data/modelc_sub/label/4659.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4659.json
# upload: data/modelc_sub/label/4669.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4669.json
# upload: data/modelc_sub/label/483.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/483.json
# upload: data/modelc_sub/label/477.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/477.json
# upload: data/modelc_sub/label/4747.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4747.json
# upload: data/modelc_sub/label/474.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/474.json
# upload: data/modelc_sub/label/4856.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4856.json
# upload: data/modelc_sub/label/486.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/486.json
# upload: data/modelc_sub/label/485.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/485.json
# upload: data/modelc_sub/label/4816.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4816.json
# upload: data/modelc_sub/label/469.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/469.json
# upload: data/modelc_sub/label/4819.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4819.json
# upload: data/modelc_sub/label/4867.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4867.json
# upload: data/modelc_sub/label/4868.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4868.json
# upload: data/modelc_sub/label/484.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/484.json
# upload: data/modelc_sub/label/4876.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4876.json
# upload: data/modelc_sub/label/4843.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4843.json
# upload: data/modelc_sub/label/488.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/488.json
# upload: data/modelc_sub/label/4878.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4878.json
# upload: data/modelc_sub/label/487.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/487.json
# upload: data/modelc_sub/label/489.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/489.json
# upload: data/modelc_sub/label/4874.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4874.json
# upload: data/modelc_sub/label/4881.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4881.json
# upload: data/modelc_sub/label/4892.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4892.json
# upload: data/modelc_sub/label/4898.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4898.json
# upload: data/modelc_sub/label/4890.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4890.json
# upload: data/modelc_sub/label/4900.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4900.json
# upload: data/modelc_sub/label/4903.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4903.json
# upload: data/modelc_sub/label/4918.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4918.json
# upload: data/modelc_sub/label/4911.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4911.json
# upload: data/modelc_sub/label/4932.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4932.json
# upload: data/modelc_sub/label/491.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/491.json
# upload: data/modelc_sub/label/4909.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4909.json
# upload: data/modelc_sub/label/4936.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4936.json
# upload: data/modelc_sub/label/4927.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4927.json
# upload: data/modelc_sub/label/4964.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4964.json
# upload: data/modelc_sub/label/4941.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4941.json
# upload: data/modelc_sub/label/4966.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4966.json
# upload: data/modelc_sub/label/4944.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4944.json
# upload: data/modelc_sub/label/4970.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4970.json
# upload: data/modelc_sub/label/4965.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4965.json
# upload: data/modelc_sub/label/4968.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4968.json
# upload: data/modelc_sub/label/4967.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4967.json
# upload: data/modelc_sub/label/4975.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4975.json
# upload: data/modelc_sub/label/4971.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4971.json
# upload: data/modelc_sub/label/4978.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4978.json
# upload: data/modelc_sub/label/4981.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4981.json
# upload: data/modelc_sub/label/4982.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4982.json
# upload: data/modelc_sub/label/4983.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4983.json
# upload: data/modelc_sub/label/4991.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4991.json
# upload: data/modelc_sub/label/4993.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4993.json
# upload: data/modelc_sub/label/498.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/498.json
# upload: data/modelc_sub/label/4990.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4990.json
# upload: data/modelc_sub/label/4992.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4992.json
# upload: data/modelc_sub/label/4979.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4979.json
# upload: data/modelc_sub/label/4994.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4994.json
# upload: data/modelc_sub/label/4999.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/4999.json
# upload: data/modelc_sub/label/502.json to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/label/502.json
# ...
# upload: data/modelc_sub/pic/6332.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6332.JPG
# upload: data/modelc_sub/pic/6368.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6368.JPG
# upload: data/modelc_sub/pic/6341.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6341.JPG
# upload: data/modelc_sub/pic/6349.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6349.JPG
# upload: data/modelc_sub/pic/6380.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6380.JPG
# upload: data/modelc_sub/pic/6346.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6346.JPG
# upload: data/modelc_sub/pic/6417.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6417.JPG
# upload: data/modelc_sub/pic/6325.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6325.JPG
# upload: data/modelc_sub/pic/6492.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6492.JPG
# upload: data/modelc_sub/pic/6366.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6366.JPG
# upload: data/modelc_sub/pic/6379.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6379.JPG
# upload: data/modelc_sub/pic/6396.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6396.jpg
# upload: data/modelc_sub/pic/6518.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6518.JPG
# upload: data/modelc_sub/pic/6512.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6512.jpg
# upload: data/modelc_sub/pic/6439.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6439.JPG
# upload: data/modelc_sub/pic/6478.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6478.JPG
# upload: data/modelc_sub/pic/6404.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6404.jpg
# upload: data/modelc_sub/pic/6525.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6525.jpg
# upload: data/modelc_sub/pic/6462.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6462.jpg
# upload: data/modelc_sub/pic/6464.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6464.jpg
# upload: data/modelc_sub/pic/6420.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6420.JPG
# upload: data/modelc_sub/pic/6584.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6584.JPG
# upload: data/modelc_sub/pic/6561.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6561.JPG
# upload: data/modelc_sub/pic/6631.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6631.jpg
# upload: data/modelc_sub/pic/6412.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6412.JPG
# upload: data/modelc_sub/pic/6636.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6636.jpg
# upload: data/modelc_sub/pic/6580.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6580.JPG
# upload: data/modelc_sub/pic/6610.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6610.JPG
# upload: data/modelc_sub/pic/6612.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6612.JPG
# upload: data/modelc_sub/pic/6574.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6574.jpg
# upload: data/modelc_sub/pic/6529.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6529.jpg
# upload: data/modelc_sub/pic/6553.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6553.JPG
# upload: data/modelc_sub/pic/6499.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6499.JPG
# upload: data/modelc_sub/pic/6635.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6635.jpg
# upload: data/modelc_sub/pic/6638.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6638.jpg
# upload: data/modelc_sub/pic/6666.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6666.JPG
# upload: data/modelc_sub/pic/6637.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6637.jpg
# upload: data/modelc_sub/pic/6721.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6721.JPG
# upload: data/modelc_sub/pic/6732.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6732.jpg
# upload: data/modelc_sub/pic/6695.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6695.JPG
# upload: data/modelc_sub/pic/6688.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6688.JPG
# upload: data/modelc_sub/pic/6747.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6747.jpg
# upload: data/modelc_sub/pic/6778.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6778.jpg
# upload: data/modelc_sub/pic/670.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/670.jpg
# upload: data/modelc_sub/pic/6750.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6750.jpg
# upload: data/modelc_sub/pic/6743.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6743.jpg
# upload: data/modelc_sub/pic/6785.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6785.jpg
# upload: data/modelc_sub/pic/6754.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6754.jpg
# upload: data/modelc_sub/pic/6660.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6660.jpg
# upload: data/modelc_sub/pic/6759.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6759.jpg
# upload: data/modelc_sub/pic/6777.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6777.jpg
# upload: data/modelc_sub/pic/6788.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6788.jpg
# upload: data/modelc_sub/pic/6794.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6794.jpg
# upload: data/modelc_sub/pic/6752.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6752.jpg
# upload: data/modelc_sub/pic/6781.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6781.jpg
# upload: data/modelc_sub/pic/6792.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6792.jpg
# upload: data/modelc_sub/pic/6805.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6805.JPG
# upload: data/modelc_sub/pic/6795.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6795.jpg
# upload: data/modelc_sub/pic/6783.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6783.jpg
# upload: data/modelc_sub/pic/6798.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6798.JPG
# upload: data/modelc_sub/pic/6809.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6809.JPG
# upload: data/modelc_sub/pic/6802.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6802.JPG
# upload: data/modelc_sub/pic/6836.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6836.JPG
# upload: data/modelc_sub/pic/6841.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6841.JPG
# upload: data/modelc_sub/pic/6818.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6818.jpg
# upload: data/modelc_sub/pic/6724.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6724.jpg
# upload: data/modelc_sub/pic/6879.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6879.JPG
# upload: data/modelc_sub/pic/688.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/688.jpg
# upload: data/modelc_sub/pic/6848.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6848.JPG
# upload: data/modelc_sub/pic/6822.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6822.jpg
# upload: data/modelc_sub/pic/6823.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6823.JPG
# upload: data/modelc_sub/pic/6843.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6843.JPG
# upload: data/modelc_sub/pic/6892.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6892.jpg
# upload: data/modelc_sub/pic/6856.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6856.JPG
# upload: data/modelc_sub/pic/6872.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6872.JPG
# upload: data/modelc_sub/pic/6919.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6919.JPG
# upload: data/modelc_sub/pic/6913.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6913.jpg
# upload: data/modelc_sub/pic/6933.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6933.JPG
# upload: data/modelc_sub/pic/6893.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6893.jpg
# upload: data/modelc_sub/pic/6816.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6816.jpg
# upload: data/modelc_sub/pic/6882.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6882.JPG
# upload: data/modelc_sub/pic/6901.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6901.jpg
# upload: data/modelc_sub/pic/690.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/690.jpg
# upload: data/modelc_sub/pic/6897.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6897.jpg
# upload: data/modelc_sub/pic/6956.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6956.JPG
# upload: data/modelc_sub/pic/6940.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6940.JPG
# upload: data/modelc_sub/pic/6936.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6936.JPG
# upload: data/modelc_sub/pic/6920.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6920.JPG
# upload: data/modelc_sub/pic/6967.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6967.jpg
# upload: data/modelc_sub/pic/6921.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6921.JPG
# upload: data/modelc_sub/pic/6971.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6971.jpg
# upload: data/modelc_sub/pic/6954.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6954.JPG
# upload: data/modelc_sub/pic/6955.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6955.JPG
# upload: data/modelc_sub/pic/6975.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6975.JPG
# upload: data/modelc_sub/pic/6961.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6961.JPG
# upload: data/modelc_sub/pic/6996.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6996.JPG
# upload: data/modelc_sub/pic/6922.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6922.JPG
# upload: data/modelc_sub/pic/6993.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6993.JPG
# upload: data/modelc_sub/pic/6994.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6994.JPG
# upload: data/modelc_sub/pic/6986.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6986.JPG
# upload: data/modelc_sub/pic/6965.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6965.JPG
# upload: data/modelc_sub/pic/6959.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6959.JPG
# upload: data/modelc_sub/pic/6943.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6943.JPG
# upload: data/modelc_sub/pic/7132.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/7132.JPG
# upload: data/modelc_sub/pic/7264.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/7264.JPG
# upload: data/modelc_sub/pic/7054.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/7054.JPG
# upload: data/modelc_sub/pic/7189.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/7189.JPG
# upload: data/modelc_sub/pic/7200.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/7200.JPG
# upload: data/modelc_sub/pic/6980.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/6980.JPG
# upload: data/modelc_sub/pic/7001.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/7001.JPG
# upload: data/modelc_sub/pic/7315.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/7315.JPG
# upload: data/modelc_sub/pic/7268.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/7268.JPG
# upload: data/modelc_sub/pic/7485.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/7485.JPG
# upload: data/modelc_sub/pic/7171.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/7171.JPG
# upload: data/modelc_sub/pic/7394.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/7394.JPG
# upload: data/modelc_sub/pic/7616.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/7616.JPG
# upload: data/modelc_sub/pic/7163.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/7163.JPG
# upload: data/modelc_sub/pic/7765.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/7765.JPG
# upload: data/modelc_sub/pic/7602.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/7602.JPG
# upload: data/modelc_sub/pic/7193.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/7193.JPG
# upload: data/modelc_sub/pic/767.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/767.jpg
# upload: data/modelc_sub/pic/8141.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/8141.JPG
# upload: data/modelc_sub/pic/7666.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/7666.JPG
# upload: data/modelc_sub/pic/7597.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/7597.JPG
# upload: data/modelc_sub/pic/8159.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/8159.JPG
# upload: data/modelc_sub/pic/7680.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/7680.JPG
# upload: data/modelc_sub/pic/8207.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/8207.JPG
# upload: data/modelc_sub/pic/7867.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/7867.JPG
# upload: data/modelc_sub/pic/7797.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/7797.JPG
# upload: data/modelc_sub/pic/8236.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/8236.JPG
# upload: data/modelc_sub/pic/8191.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/8191.JPG
# upload: data/modelc_sub/pic/7682.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/7682.JPG
# upload: data/modelc_sub/pic/7811.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/7811.JPG
# upload: data/modelc_sub/pic/8466.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/8466.JPG
# upload: data/modelc_sub/pic/8188.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/8188.JPG
# upload: data/modelc_sub/pic/8341.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/8341.JPG
# upload: data/modelc_sub/pic/8228.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/8228.JPG
# upload: data/modelc_sub/pic/8307.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/8307.JPG
# upload: data/modelc_sub/pic/8284.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/8284.JPG
# upload: data/modelc_sub/pic/8591.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/8591.JPG
# upload: data/modelc_sub/pic/817.jpg to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/817.jpg
# upload: data/modelc_sub/pic/8632.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/8632.JPG
# upload: data/modelc_sub/pic/9428.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/9428.JPG
# upload: data/modelc_sub/pic/8231.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/8231.JPG
# upload: data/modelc_sub/pic/9550.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/9550.JPG
# upload: data/modelc_sub/pic/9778.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/9778.JPG
# upload: data/modelc_sub/pic/9198.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/9198.JPG
# upload: data/modelc_sub/pic/9602.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/9602.JPG
# upload: data/modelc_sub/pic/8966.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/8966.JPG
# upload: data/modelc_sub/pic/9185.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/9185.JPG
# upload: data/modelc_sub/pic/8850.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/8850.JPG
# upload: data/modelc_sub/pic/9784.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/9784.JPG
# upload: data/modelc_sub/pic/9931.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/9931.JPG
# upload: data/modelc_sub/pic/9719.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/9719.JPG
# upload: data/modelc_sub/pic/9777.JPG to s3://lianbao-mask-rcnn/DEMO-Mask-R-CNN/modelc_sub/pic/9777.JPG

# %%
data_location = "s3://{}/{}".format('lianbao-mask-rcnn', prefix)

# %%
data_location
# Out:
# 's3://lianbao-mask-rcnn/DEMO-Mask-R-CNN'

# %% [markdown]
# ## Create an estimator and fit the model
#
# In order to use SageMaker to fit our algorithm, we'll create an `Estimator` that defines how to use the container to train. This includes the configuration we need to invoke SageMaker training:
#
# * The __container name__. This is constructed as in the shell commands above.
# * The __role__. As defined above.
# * The __instance count__ which is the number of machines to use for training.
# * The __instance type__ which is the type of machine to use for training.
# * The __output path__ determines where the model artifact will be written.
# * The __session__ is the SageMaker session object that we defined above.
#
# Then we use fit() on the estimator to train against the data that we uploaded above.

# %%
account = sess.boto_session.client('sts').get_caller_identity()['Account']
region = sess.boto_session.region_name
image = '{}.dkr.ecr.{}.amazonaws.com/modelc:latest'.format(account, region)

maskrcnn = sage.estimator.Estimator(image,
                       role, 1, 'ml.p2.xlarge',
                       output_path="s3://{}/output".format(sess.default_bucket()),
                       sagemaker_session=sess)
#please adjust hyperparameters as needed. 
maskrcnn.set_hyperparameters(num_epochs = 1,
                              model_type = 'modelc_sub')

maskrcnn.fit(data_location)
# Out:
# 2021-02-01 09:36:16 Starting - Starting the training job...
# 2021-02-01 09:36:39 Starting - Launching requested ML instancesProfilerReport-1612172175: InProgress
# ......
# 2021-02-01 09:37:40 Starting - Preparing the instances for training......
# 2021-02-01 09:38:45 Downloading - Downloading input data
# 2021-02-01 09:38:45 Training - Downloading the training image.....................
# 2021-02-01 09:42:03 Training - Training image download completed. Training in progress.Starting the training.
# {'model_type': 'modelc_sub', 'num_epochs': '1'}
# /opt/ml/input/data/training/modelc_sub
# ['.ipynb_checkpoints', '.DS_Store', 'label', 'pic']
# Downloading: "https://download.pytorch.org/models/maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth" to /root/.cache/torch/checkpoints/maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth
# #015  0%|          | 0.00/170M [00:00<?, ?B/s]#015  1%|          | 1.77M/170M [00:00<00:09, 18.6MB/s]#015  6%|▌         | 9.98M/170M [00:00<00:06, 24.3MB/s]#015 11%|█         | 18.2M/170M [00:00<00:05, 31.0MB/s]#015 16%|█▌        | 26.3M/170M [00:00<00:03, 38.3MB/s]#015 19%|█▉        | 31.9M/170M [00:00<00:03, 42.4MB/s]#015 22%|██▏       | 37.4M/170M [00:00<00:03, 45.3MB/s]#015 25%|██▌       | 42.8M/170M [00:00<00:02, 45.5MB/s]#015 29%|██▊       | 48.8M/170M [00:00<00:02, 49.6MB/s]#015 33%|███▎      | 55.4M/170M [00:00<00:02, 54.0MB/s]#015 37%|███▋      | 62.1M/170M [00:01<00:01, 57.7MB/s]#015 41%|████      | 69.1M/170M [00:01<00:01, 60.9MB/s]#015 45%|████▍     | 76.1M/170M [00:01<00:01, 63.8MB/s]#015 49%|████▉     | 83.0M/170M [00:01<00:01, 65.8MB/s]#015 53%|█████▎    | 89.8M/170M [00:01<00:01, 66.9MB/s]#015 57%|█████▋    | 96.6M/170M [00:01<00:01, 67.6MB/s]#015 61%|██████    | 103M/170M [00:01<00:01, 67.3MB/s] #015 65%|██████▍   | 110M/170M [00:01<00:00, 64.0MB/s]#015 68%|██████▊   | 116M/170M [00:01<00:00, 63.7MB/s]#015 73%|███████▎  | 123M/170M [00:01<00:00, 67.1MB/s]#015 76%|███████▋  | 130M/170M [00:02<00:00, 67.9MB/s]#015 80%|████████  | 136M/170M [00:02<00:00, 63.5MB/s]#015 85%|████████▍ | 144M/170M [00:02<00:00, 65.9MB/s]#015 89%|████████▊ | 150M/170M [00:02<00:00, 67.7MB/s]#015 92%|█████████▏| 157M/170M [00:02<00:00, 62.7MB/s]#015 98%|█████████▊| 166M/170M [00:02<00:00, 69.4MB/s]#015100%|██████████| 170M/170M [00:02<00:00, 66.4MB/s]
# Epoch: [0]  [  0/476]  eta: 0:22:49  lr: 0.000016  loss: 6.8127 (6.8127)  loss_classifier: 1.9419 (1.9419)  loss_box_reg: 0.0034 (0.0034)  loss_mask: 4.6014 (4.6014)  loss_objectness: 0.2580 (0.2580)  loss_rpn_box_reg: 0.0080 (0.0080)  time: 2.8780  data: 0.5573  max mem: 2139
# Epoch: [0]  [ 10/476]  eta: 0:12:37  lr: 0.000121  loss: 4.8902 (5.0332)  loss_classifier: 1.9147 (1.8230)  loss_box_reg: 0.2202 (0.1971)  loss_mask: 2.5340 (2.5960)  loss_objectness: 0.2383 (0.3531)  loss_rpn_box_reg: 0.0457 (0.0639)  time: 1.6248  data: 0.0666  max mem: 2429
# Epoch: [0]  [ 20/476]  eta: 0:12:03  lr: 0.000226  loss: 3.9655 (3.8879)  loss_classifier: 1.1204 (1.2913)  loss_box_reg: 0.1937 (0.1853)  loss_mask: 1.5932 (1.8368)  loss_objectness: 0.1895 (0.4609)  loss_rpn_box_reg: 0.0458 (0.1137)  time: 1.5225  data: 0.0141  max mem: 2876
# Epoch: [0]  [ 30/476]  eta: 0:11:32  lr: 0.000331  loss: 1.4666 (3.3196)  loss_classifier: 0.4230 (0.9795)  loss_box_reg: 0.1508 (0.1733)  loss_mask: 0.7039 (1.4512)  loss_objectness: 0.1037 (0.4885)  loss_rpn_box_reg: 0.0569 (0.2270)  time: 1.5113  data: 0.0102  max mem: 2876
# Epoch: [0]  [ 40/476]  eta: 0:11:09  lr: 0.000436  loss: 1.4172 (2.9705)  loss_classifier: 0.3313 (0.8263)  loss_box_reg: 0.1511 (0.1713)  loss_mask: 0.6147 (1.2504)  loss_objectness: 0.1515 (0.4528)  loss_rpn_box_reg: 0.0366 (0.2697)  time: 1.4810  data: 0.0105  max mem: 2876
# Epoch: [0]  [ 50/476]  eta: 0:10:49  lr: 0.000541  loss: 1.3997 (2.7043)  loss_classifier: 0.2794 (0.7164)  loss_box_reg: 0.1511 (0.1652)  loss_mask: 0.5819 (1.1277)  loss_objectness: 0.1912 (0.4031)  loss_rpn_box_reg: 0.0438 (0.2920)  time: 1.4806  data: 0.0119  max mem: 2876
# Epoch: [0]  [ 60/476]  eta: 0:10:30  lr: 0.000646  loss: 1.1814 (2.5077)  loss_classifier: 0.2395 (0.6405)  loss_box_reg: 0.1344 (0.1591)  loss_mask: 0.5198 (1.0207)  loss_objectness: 0.1114 (0.3726)  loss_rpn_box_reg: 0.0499 (0.3148)  time: 1.4761  data: 0.0112  max mem: 2876
# /opt/conda/lib/python3.6/site-packages/PIL/JpegImagePlugin.py:793: UserWarning: Image appears to be a malformed MPO file, it will be interpreted as a base JPEG file
#   "Image appears to be a malformed MPO file, it will be "
# Epoch: [0]  [ 70/476]  eta: 0:10:15  lr: 0.000752  loss: 1.1451 (2.3575)  loss_classifier: 0.2426 (0.5906)  loss_box_reg: 0.1385 (0.1596)  loss_mask: 0.4931 (0.9564)  loss_objectness: 0.1196 (0.3419)  loss_rpn_box_reg: 0.0499 (0.3090)  time: 1.4989  data: 0.0099  max mem: 2876
# Epoch: [0]  [ 80/476]  eta: 0:09:59  lr: 0.000857  loss: 1.1561 (2.2915)  loss_classifier: 0.2612 (0.5492)  loss_box_reg: 0.1447 (0.1585)  loss_mask: 0.5118 (0.9095)  loss_objectness: 0.0989 (0.3210)  loss_rpn_box_reg: 0.0585 (0.3534)  time: 1.5058  data: 0.0106  max mem: 2876
# Epoch: [0]  [ 90/476]  eta: 0:09:43  lr: 0.000962  loss: 1.2038 (2.1643)  loss_classifier: 0.2647 (0.5199)  loss_box_reg: 0.1450 (0.1613)  loss_mask: 0.5160 (0.8666)  loss_objectness: 0.0781 (0.2955)  loss_rpn_box_reg: 0.0296 (0.3210)  time: 1.4945  data: 0.0107  max mem: 2876
# Epoch: [0]  [100/476]  eta: 0:09:28  lr: 0.001067  loss: 1.1014 (2.0783)  loss_classifier: 0.2668 (0.4946)  loss_box_reg: 0.1693 (0.1622)  loss_mask: 0.5106 (0.8310)  loss_objectness: 0.0596 (0.2819)  loss_rpn_box_reg: 0.0296 (0.3086)  time: 1.5115  data: 0.0099  max mem: 2876
# Epoch: [0]  [110/476]  eta: 0:09:13  lr: 0.001172  loss: 1.1617 (2.0271)  loss_classifier: 0.2688 (0.4764)  loss_box_reg: 0.1612 (0.1645)  loss_mask: 0.4783 (0.8049)  loss_objectness: 0.0582 (0.2711)  loss_rpn_box_reg: 0.0350 (0.3103)  time: 1.5140  data: 0.0097  max mem: 2876

# %% [markdown]
# ## Hosting your model
# You can use a trained model to get real time predictions using HTTP endpoint. Follow these steps to walk you through the process.

# %% [markdown]
# ### Deploy the model
#
# Deploying the model to SageMaker hosting just requires a `deploy` call on the fitted model. This call takes an instance count, instance type, and optionally serializer and deserializer functions. These are used when the resulting predictor is created on the endpoint.

# %%
#from sagemaker.predictor import csv_serializer
predictor = maskrcnn.deploy(1, 
                            'ml.p2.xlarge', 
                            endpoint_name='mask-r-cnn-lianbao') #, update_endpoint=True)

# %% [markdown]
# ### Choose some data and use it for a prediction
#
# In order to do some predictions, we'll extract some of the data we used for training and do predictions against it. This is, of course, bad statistical practice, but a good way to see how the mechanism works.

# %%
from PIL import Image
import numpy as np
import pickle

# %%
import json
import time
import io

def test_image_using_img_bytes(fn):
    print('Opening image: {}...'.format(fn))
    pil_img = Image.open(fn)
    print('Image size is: {}...'.format(pil_img.size))
    
    if pil_img.size[0] * pil_img.size[1] > 5000000:
        print('Too big to pass to an SM endpoint, exiting\n')
    else:
        display(pil_img)
        
        print('Finding the walkers...')

        buf = io.BytesIO()
        pil_img.save(buf, format='JPEG')
        byte_im = buf.getvalue()

        start_time = time.time()
        result = predictor.predict(byte_im)
        print('...took {:.2f} seconds'.format(time.time() - start_time))
        
        prediction = json.loads(result)
        print('Found {} people walking in that image'.format(len(prediction)))
        for i in range(len(prediction)):
            x = Image.fromarray(np.uint8(np.asarray(prediction[i][0])*255))
            display(x)

# %%
test_images = ['FudanPed00001.png']

# %%
for i in test_images:
    test_image_using_img_bytes(i)

# %%
test_image_using_img_bytes(test_images[0])

# %% [markdown]
# ### Optional cleanup
# When you're done with the endpoint, you'll want to clean it up.

# %%
sess.delete_endpoint(predictor.endpoint)
